# %%
# importing pandas, matplotlib and seaborn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#reading the csv file i.e our data 
data = pd.read_csv('Sleep_health_and_lifestyle_dataset.csv')
data
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
#Getting information about our data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           374 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
# Number of rows and columns
data.shape
# Out:
# (374, 13)

# %%
# mapping categories of quality of sleep
sleep_quality_map = {1:'Poor',2:'Poor',3:'Poor',4:'Poor', 5:'Good',6:'Good',7:'Good',8:'Excellent',9:'Excellent', 10:'Excellent'}
data['sleep_quality'] = data['Quality of Sleep'].map(sleep_quality_map)
data
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
# People with poor qality of sleep i.e less than 5
data.loc[data['Quality of Sleep']<5]
# Out:
#     Person ID  Gender  Age            Occupation  Sleep Duration  \
# 3           4    Male   28  Sales Representative             5.9
# 4           5    Male   28  Sales Representative             5.9
# 5           6    Male   28     Software Engineer             5.9
# 80         81  Female   34             Scientist             5.8
# 81         82  Female   34             Scientist             5.8
#
#     Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 3                  4                       30             8        Obese
# 4                  4                       30             8        Obese
# 5                  4                       30             8        Obese
# 80                 4                       32             8   Overweight
# 81                 4                       32             8   Overweight
#
#    Blood Pressure  Heart Rate  Daily Steps Sleep Disorder sleep_quality
# ...

# %%
# Viewing Quality of Sleep vs sleep_quality column which we added
data.iloc[:, 5:14:8]
# Out:
#      Quality of Sleep sleep_quality
# 0                   6          Good
# 1                   6          Good
# 2                   6          Good
# 3                   4          Poor
# 4                   4          Poor
# ..                ...           ...
# 369                 9     Excellent
# 370                 9     Excellent
# 371                 9     Excellent
# 372                 9     Excellent
# 373                 9     Excellent
#
# [374 rows x 2 columns]

# %%
#The columns present in our data
data.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder', 'sleep_quality'],
#       dtype='object')

# %%
# function of BMI values
def BMI_values(BMI):
    if BMI == 'Underweight':
        return 'Below 18'
    elif BMI == 'Normal' or BMI == 'Normal Weight':
        return '18 to 25'
    elif BMI == 'Overweight':
        return '25 to 30'
    elif BMI == 'Obese':
        return 'Above 30'

# %%
#Applying our function
data['BMI_Values'] = data['BMI Category'].apply(BMI_values)
data.head(10)
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
# 5          6   Male   28     Software Engineer             5.9
# 6          7   Male   29               Teacher             6.3
# 7          8   Male   29                Doctor             7.8
# 8          9   Male   29                Doctor             7.8
# 9         10   Male   29                Doctor             7.8
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# ...

# %%
# information of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           374 non-null    object
#  13  sleep_quality            374 non-null    object
# ...

# %%
# mean of the column called Age
data['Age'].mean()
# Out:
# 42.18449197860963

# %%
# standard deviation of column called Age
data['Age'].std()
# Out:
# 8.673133465547243

# %%
# Boxplot of the column Age using matplotlib
plt.figure(figsize=(10,8))
plt.boxplot(data['Age'])
plt.title('Age Distribution')
plt.ylabel('Ages')
plt.show()

# %%
#Histogram of column Age using matplotlib
plt.figure(figsize = (10,8))
plt.hist(data['Age'], bins=10, label = "ages", color = 'pink')
plt.title('Age Distribution')
plt.xlabel('Ages')
plt.ylabel('Frequencies')
plt.legend(loc = 2)
plt.show()

# %%
# 2 line plots(Sleep Duration vs Quality of Sleep and Sleep Duration vs Stress Level) using matplotlib
fig, ax = plt.subplots(figsize = (18,8))
ax.plot(data['Sleep Duration'], data['Quality of Sleep'], color = 'purple', lw = 2, ls = ':')
ax.plot(data['Sleep Duration'], data['Stress Level'], color = 'green', ls = '-.')
ax.set_title('Sleep Duration vs Quality of Sleep / Stress Level')
ax.set_xlabel("Sleep Duration")
ax.set_ylabel("Quality of Sleep / Stress Level")
ax.legend(["Duration vs Quality", "Duration vs Stress"], loc = 3)

# %%
# Bargraph of Occupation vs Sleep Duration using seaborn
sns.set(rc={'figure.figsize':(22,6)}) 
sns.set_context('talk')
sns.set_style('darkgrid')
sns.barplot(data['Occupation'], data['Sleep Duration'])
# Out:
# c:\Users\user\anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Occupation', ylabel='Sleep Duration'>

# %%
# Scatter plot of Daily Steps vs Heart Rate using seaborn
sns.scatterplot(data['Daily Steps'], data['Heart Rate'])
# Out:
# c:\Users\user\anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Daily Steps', ylabel='Heart Rate'>
